# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# Cropping with PIL

# %%
# Load the image
image = cv2.imread(r"/content/drive/MyDrive/Colab Notebooks/images/lenna.png")

# Defining shearing factors(adjust as needed)
tx = 50
ty = 200
angle = 45
scale = 200/512

# rotate this image in 200x200 at the top
# left corner of the image

a = np.cos(np.radians(angle)) * scale   #shearing along x axis
b = np.sin(np.radians(angle)) * scale   #shearing along y axis
shear_x = 0.3
shear_y = 0.2

#Create a transformation matrix
M = np.float32([[1, 0.5, tx], [-0.5, 1, ty]])

#Warp the image
warped_image = cv2.warpAffine(image, M, (image.shape[1], image.shape[0]))

cv2_imshow(warped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
